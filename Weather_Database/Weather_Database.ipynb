# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
Weather_cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city =  city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in Weather_cities:
        Weather_cities.append(city)
# Print the city count to confirm sufficient count
len( Weather_cities)
# Out:
# 602

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(Weather_cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dixon
# Processing Record 2 of Set 1 | richards bay
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | jalu
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | mount gambier
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | tala
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | ostrovnoy
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | sena madureira
# Processing Record 18 of Set 1 | praia
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | puerto ayacucho
# Processing Record 21 of Set 1 | itaituba
# Processing Record 22 of Set 1 | mattawa
# Processing Record 23 of Set 1 | chimbote
# Processing Record 24 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 1 | marystown
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | rocha
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | honiara
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | grand-lahou
# Processing Record 33 of Set 1 | gibara
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | caceres
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | la ronge
# Processing Record 40 of Set 1 | yeppoon
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | coquimbo
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | vestmannaeyjar
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | koslan
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | presidencia roque saenz pena
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | mercedes
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | teya
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | salalah
# Processing Record 12 of Set 2 | san ramon de la nueva oran
# Processing Record 13 of Set 2 | naze
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | emba
# Processing Record 16 of Set 2 | sola
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | araouane
# Processing Record 20 of Set 2 | bam
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | huarmey
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | hegra
# Processing Record 26 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | caravelas
# Processing Record 30 of Set 2 | morehead
# Processing Record 31 of Set 2 | takoradi
# Processing Record 32 of Set 2 | praia da vitoria
# Processing Record 33 of Set 2 | bucerias
# Processing Record 34 of Set 2 | fallon
# Processing Record 35 of Set 2 | pizarro
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | bouca
# Processing Record 38 of Set 2 | soyo
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | yicheng
# Processing Record 41 of Set 2 | lavrentiya
# Processing Record 42 of Set 2 | grand-bourg
# Processing Record 43 of Set 2 | pemberton
# Processing Record 44 of Set 2 | dubbo
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | portland
# Processing Record 47 of Set 2 | fuyang
# Processing Record 48 of Set 2 | geraldton
# Processing Record 49 of Set 2 | riyadh
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | necochea
# Processing Record 3 of Set 3 | kosh-agach
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | oranjestad
# Processing Record 7 of Set 3 | vao
# Processing Record 8 of Set 3 | sisophon
# Processing Record 9 of Set 3 | kurchum
# Processing Record 10 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | muisne
# Processing Record 16 of Set 3 | nisia floresta
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | bilma
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | dukat
# Processing Record 21 of Set 3 | molina
# Processing Record 22 of Set 3 | bumba
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | flinders
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | xinqing
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | opuwo
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | cap malheureux
# Processing Record 33 of Set 3 | broome
# Processing Record 34 of Set 3 | labuhan
# Processing Record 35 of Set 3 | holme
# Processing Record 36 of Set 3 | etaples
# Processing Record 37 of Set 3 | sorland
# Processing Record 38 of Set 3 | itarema
# Processing Record 39 of Set 3 | coos bay
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | natal
# Processing Record 42 of Set 3 | havelock
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | beloretsk
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | jurado
# Processing Record 47 of Set 3 | sisimiut
# Processing Record 48 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | roald
# Processing Record 2 of Set 4 | necsesti
# Processing Record 3 of Set 4 | adrar
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | colares
# Processing Record 6 of Set 4 | diapaga
# Processing Record 7 of Set 4 | comodoro rivadavia
# Processing Record 8 of Set 4 | baruun-urt
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | awjilah
# Processing Record 11 of Set 4 | kaeo
# Processing Record 12 of Set 4 | acapulco
# Processing Record 13 of Set 4 | pontianak
# Processing Record 14 of Set 4 | talcahuano
# Processing Record 15 of Set 4 | bonavista
# Processing Record 16 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | blackwater
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | srednekolymsk
# Processing Record 21 of Set 4 | jardim
# Processing Record 22 of Set 4 | ucluelet
# Processing Record 23 of Set 4 | siavonga
# Processing Record 24 of Set 4 | conde
# Processing Record 25 of Set 4 | waling
# Processing Record 26 of Set 4 | ardabil
# Processing Record 27 of Set 4 | kalengwa
# Processing Record 28 of Set 4 | kayes
# Processing Record 29 of Set 4 | pangai
# Processing Record 30 of Set 4 | stornoway
# Processing Record 31 of Set 4 | mwinilunga
# Processing Record 32 of Set 4 | lushunkou
# City not found. Skipping...
# Processing Record 33 of Set 4 | moron
# Processing Record 34 of Set 4 | ibra
# Processing Record 35 of Set 4 | victoria
# Processing Record 36 of Set 4 | axim
# Processing Record 37 of Set 4 | arlit
# Processing Record 38 of Set 4 | mareeba
# Processing Record 39 of Set 4 | westport
# Processing Record 40 of Set 4 | ayacucho
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | coihaique
# Processing Record 43 of Set 4 | pauini
# Processing Record 44 of Set 4 | avera
# Processing Record 45 of Set 4 | marawi
# Processing Record 46 of Set 4 | zaozerne
# Processing Record 47 of Set 4 | hasaki
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | nenjiang
# Processing Record 50 of Set 4 | rundu
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 2 of Set 5 | quatre cocos
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | alice springs
# Processing Record 5 of Set 5 | nagato
# Processing Record 6 of Set 5 | zhangjiakou
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | faanui
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | ferrol
# Processing Record 12 of Set 5 | washougal
# Processing Record 13 of Set 5 | kavieng
# Processing Record 14 of Set 5 | bosaso
# Processing Record 15 of Set 5 | thessalon
# Processing Record 16 of Set 5 | mount pleasant
# Processing Record 17 of Set 5 | east london
# Processing Record 18 of Set 5 | kloulklubed
# Processing Record 19 of Set 5 | amga
# Processing Record 20 of Set 5 | salinopolis
# Processing Record 21 of Set 5 | touros
# Processing Record 22 of Set 5 | rio gallegos
# Processing Record 23 of Set 5 | barabai
# Processing Record 24 of Set 5 | kharakvasla
# Processing Record 25 of Set 5 | kavaratti
# Processing Record 26 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 5 | yerbogachen
# Processing Record 28 of Set 5 | muros
# Processing Record 29 of Set 5 | isabela
# Processing Record 30 of Set 5 | bathsheba
# Processing Record 31 of Set 5 | san patricio
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | asosa
# Processing Record 34 of Set 5 | tonantins
# Processing Record 35 of Set 5 | riberalta
# Processing Record 36 of Set 5 | shakiso
# Processing Record 37 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 5 | hirara
# Processing Record 39 of Set 5 | chipinge
# Processing Record 40 of Set 5 | boulder
# Processing Record 41 of Set 5 | awbari
# Processing Record 42 of Set 5 | shimoda
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | cockburn town
# Processing Record 45 of Set 5 | santiago del estero
# Processing Record 46 of Set 5 | salekhard
# Processing Record 47 of Set 5 | lota
# Processing Record 48 of Set 5 | seminole
# Processing Record 49 of Set 5 | murgab
# Processing Record 50 of Set 5 | yumen
# Processing Record 1 of Set 6 | bembereke
# Processing Record 2 of Set 6 | hamilton
# Processing Record 3 of Set 6 | olafsvik
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | cardston
# Processing Record 6 of Set 6 | samarinda
# Processing Record 7 of Set 6 | port keats
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | kahului
# Processing Record 10 of Set 6 | cabo san lucas
# Processing Record 11 of Set 6 | moose factory
# Processing Record 12 of Set 6 | kivertsi
# Processing Record 13 of Set 6 | bonfim
# Processing Record 14 of Set 6 | gamba
# Processing Record 15 of Set 6 | tezu
# Processing Record 16 of Set 6 | burgos
# Processing Record 17 of Set 6 | bekobod
# Processing Record 18 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 6 | talaya
# Processing Record 20 of Set 6 | abha
# Processing Record 21 of Set 6 | sabibah
# City not found. Skipping...
# Processing Record 22 of Set 6 | almeirim
# Processing Record 23 of Set 6 | lufilufi
# Processing Record 24 of Set 6 | egvekinot
# Processing Record 25 of Set 6 | tabuk
# Processing Record 26 of Set 6 | pokhara
# Processing Record 27 of Set 6 | nishihara
# Processing Record 28 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | mucurapo
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | clemson
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | saskylakh
# Processing Record 34 of Set 6 | belaya gora
# Processing Record 35 of Set 6 | tres lagoas
# Processing Record 36 of Set 6 | san quintin
# Processing Record 37 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 6 | nemuro
# Processing Record 39 of Set 6 | hervey bay
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | ahipara
# Processing Record 43 of Set 6 | pasighat
# Processing Record 44 of Set 6 | oussouye
# Processing Record 45 of Set 6 | iquique
# Processing Record 46 of Set 6 | carnarvon
# Processing Record 47 of Set 6 | constitucion
# Processing Record 48 of Set 6 | ust-omchug
# Processing Record 49 of Set 6 | ponta delgada
# Processing Record 50 of Set 6 | oktyabrskoye
# Processing Record 1 of Set 7 | anqing
# Processing Record 2 of Set 7 | banjar
# Processing Record 3 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 7 | north branch
# Processing Record 5 of Set 7 | xichang
# Processing Record 6 of Set 7 | ilanskiy
# Processing Record 7 of Set 7 | bambous virieux
# Processing Record 8 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 7 | chirongui
# Processing Record 10 of Set 7 | marsala
# Processing Record 11 of Set 7 | airai
# Processing Record 12 of Set 7 | morondava
# Processing Record 13 of Set 7 | shingu
# Processing Record 14 of Set 7 | abay
# Processing Record 15 of Set 7 | nouadhibou
# Processing Record 16 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 7 | pechenga
# Processing Record 18 of Set 7 | ternate
# Processing Record 19 of Set 7 | komsomolskiy
# Processing Record 20 of Set 7 | bethel
# Processing Record 21 of Set 7 | lapithos
# Processing Record 22 of Set 7 | sao felix do xingu
# Processing Record 23 of Set 7 | ahuimanu
# Processing Record 24 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 7 | tupik
# Processing Record 26 of Set 7 | upernavik
# Processing Record 27 of Set 7 | bowen
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | yeniseysk
# Processing Record 30 of Set 7 | husavik
# Processing Record 31 of Set 7 | henties bay
# Processing Record 32 of Set 7 | dovers
# Processing Record 33 of Set 7 | bontang
# Processing Record 34 of Set 7 | ixtapa
# Processing Record 35 of Set 7 | amos
# Processing Record 36 of Set 7 | bereda
# Processing Record 37 of Set 7 | mahon
# Processing Record 38 of Set 7 | luwuk
# Processing Record 39 of Set 7 | leningradskiy
# Processing Record 40 of Set 7 | sept-iles
# Processing Record 41 of Set 7 | palaiokhora
# City not found. Skipping...
# Processing Record 42 of Set 7 | owando
# Processing Record 43 of Set 7 | bandarbeyla
# Processing Record 44 of Set 7 | corner brook
# Processing Record 45 of Set 7 | aras
# Processing Record 46 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 7 | port-gentil
# Processing Record 48 of Set 7 | linxia
# Processing Record 49 of Set 7 | naron
# Processing Record 50 of Set 7 | paamiut
# Processing Record 1 of Set 8 | tommot
# Processing Record 2 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 3 of Set 8 | chumikan
# Processing Record 4 of Set 8 | wagar
# Processing Record 5 of Set 8 | maragogi
# Processing Record 6 of Set 8 | agapovka
# Processing Record 7 of Set 8 | ventspils
# Processing Record 8 of Set 8 | lakes entrance
# Processing Record 9 of Set 8 | preobrazheniye
# Processing Record 10 of Set 8 | hanzhong
# Processing Record 11 of Set 8 | cayenne
# Processing Record 12 of Set 8 | paita
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 8 | conceicao da barra
# Processing Record 16 of Set 8 | asfi
# Processing Record 17 of Set 8 | omboue
# Processing Record 18 of Set 8 | sulangan
# Processing Record 19 of Set 8 | balabac
# Processing Record 20 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 8 | anori
# Processing Record 23 of Set 8 | mujiayingzi
# Processing Record 24 of Set 8 | merauke
# Processing Record 25 of Set 8 | molepolole
# Processing Record 26 of Set 8 | marathon
# Processing Record 27 of Set 8 | beysehir
# Processing Record 28 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 8 | svecha
# Processing Record 30 of Set 8 | tautira
# Processing Record 31 of Set 8 | molokovo
# Processing Record 32 of Set 8 | jamame
# Processing Record 33 of Set 8 | ikungi
# Processing Record 34 of Set 8 | codrington
# Processing Record 35 of Set 8 | waiouru
# Processing Record 36 of Set 8 | belmonte
# Processing Record 37 of Set 8 | ishigaki
# Processing Record 38 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 8 | nortelandia
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | bintulu
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | mokshan
# Processing Record 44 of Set 8 | thinadhoo
# Processing Record 45 of Set 8 | hauterive
# Processing Record 46 of Set 8 | ngunguru
# Processing Record 47 of Set 8 | buraydah
# Processing Record 48 of Set 8 | pascagoula
# Processing Record 49 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 8 | ilhabela
# Processing Record 1 of Set 9 | waingapu
# Processing Record 2 of Set 9 | kargasok
# Processing Record 3 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 4 of Set 9 | kushmurun
# Processing Record 5 of Set 9 | pimenta bueno
# Processing Record 6 of Set 9 | roslavl
# Processing Record 7 of Set 9 | ostersund
# Processing Record 8 of Set 9 | klyuchevskiy
# Processing Record 9 of Set 9 | lagoa
# Processing Record 10 of Set 9 | khrustalnyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | bayir
# Processing Record 12 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 9 | nur
# Processing Record 14 of Set 9 | kununurra
# Processing Record 15 of Set 9 | yar-sale
# Processing Record 16 of Set 9 | kargil
# Processing Record 17 of Set 9 | sexsmith
# Processing Record 18 of Set 9 | lampazos de naranjo
# Processing Record 19 of Set 9 | guthrie
# Processing Record 20 of Set 9 | taltal
# Processing Record 21 of Set 9 | svetlogorsk
# Processing Record 22 of Set 9 | zyryanka
# Processing Record 23 of Set 9 | vostok
# Processing Record 24 of Set 9 | bayan
# Processing Record 25 of Set 9 | san ignacio
# Processing Record 26 of Set 9 | kutum
# Processing Record 27 of Set 9 | kardailovo
# Processing Record 28 of Set 9 | kauhajoki
# Processing Record 29 of Set 9 | narsaq
# Processing Record 30 of Set 9 | sabang
# Processing Record 31 of Set 9 | nizwa
# Processing Record 32 of Set 9 | katangli
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | atar
# Processing Record 35 of Set 9 | lazaro cardenas
# Processing Record 36 of Set 9 | pacific grove
# Processing Record 37 of Set 9 | xinzhou
# Processing Record 38 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 9 | kaitangata
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | berezovyy
# Processing Record 42 of Set 9 | coolum beach
# Processing Record 43 of Set 9 | gagarin
# Processing Record 44 of Set 9 | faya
# Processing Record 45 of Set 9 | kinston
# Processing Record 46 of Set 9 | madera
# Processing Record 47 of Set 9 | sao jose da coroa grande
# Processing Record 48 of Set 9 | waipawa
# Processing Record 49 of Set 9 | kindu
# Processing Record 50 of Set 9 | marzuq
# Processing Record 1 of Set 10 | baherden
# Processing Record 2 of Set 10 | abu samrah
# Processing Record 3 of Set 10 | turukhansk
# Processing Record 4 of Set 10 | pangnirtung
# Processing Record 5 of Set 10 | tokoroa
# Processing Record 6 of Set 10 | zhuanghe
# Processing Record 7 of Set 10 | jizan
# Processing Record 8 of Set 10 | krasnoselkup
# Processing Record 9 of Set 10 | gulariya
# Processing Record 10 of Set 10 | taunggyi
# Processing Record 11 of Set 10 | ngerengere
# Processing Record 12 of Set 10 | ranfurly
# Processing Record 13 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 10 | mackay
# Processing Record 15 of Set 10 | cotonou
# Processing Record 16 of Set 10 | pasni
# Processing Record 17 of Set 10 | aksu
# Processing Record 18 of Set 10 | tumpat
# Processing Record 19 of Set 10 | outjo
# Processing Record 20 of Set 10 | makakilo city
# Processing Record 21 of Set 10 | west bay
# Processing Record 22 of Set 10 | yashkul
# Processing Record 23 of Set 10 | katerero
# Processing Record 24 of Set 10 | huejuquilla el alto
# Processing Record 25 of Set 10 | zaranj
# Processing Record 26 of Set 10 | segovia
# Processing Record 27 of Set 10 | yerofey pavlovich
# Processing Record 28 of Set 10 | lewisporte
# Processing Record 29 of Set 10 | leshukonskoye
# Processing Record 30 of Set 10 | say
# Processing Record 31 of Set 10 | singaraja
# Processing Record 32 of Set 10 | north bend
# Processing Record 33 of Set 10 | katobu
# Processing Record 34 of Set 10 | bacolod
# Processing Record 35 of Set 10 | lata
# Processing Record 36 of Set 10 | lorengau
# Processing Record 37 of Set 10 | damietta
# Processing Record 38 of Set 10 | pinyug
# Processing Record 39 of Set 10 | klaksvik
# Processing Record 40 of Set 10 | nara
# Processing Record 41 of Set 10 | edson
# Processing Record 42 of Set 10 | nome
# Processing Record 43 of Set 10 | fomboni
# Processing Record 44 of Set 10 | lubango
# Processing Record 45 of Set 10 | shebalino
# Processing Record 46 of Set 10 | puerto cabezas
# Processing Record 47 of Set 10 | port hedland
# Processing Record 48 of Set 10 | dingle
# Processing Record 49 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 10 | la palma
# Processing Record 1 of Set 11 | ashqelon
# Processing Record 2 of Set 11 | heishan
# Processing Record 3 of Set 11 | chokwe
# Processing Record 4 of Set 11 | kemijarvi
# Processing Record 5 of Set 11 | kattivakkam
# Processing Record 6 of Set 11 | trairi
# Processing Record 7 of Set 11 | vitim
# Processing Record 8 of Set 11 | teterow
# Processing Record 9 of Set 11 | svay rieng
# Processing Record 10 of Set 11 | tiksi
# Processing Record 11 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 11 | filadelfia
# Processing Record 13 of Set 11 | la asuncion
# Processing Record 14 of Set 11 | mbekenyera
# Processing Record 15 of Set 11 | jumla
# Processing Record 16 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 17 of Set 11 | sioux lookout
# Processing Record 18 of Set 11 | rorvik
# Processing Record 19 of Set 11 | limon
# Processing Record 20 of Set 11 | mehran
# Processing Record 21 of Set 11 | lander
# Processing Record 22 of Set 11 | nacala
# Processing Record 23 of Set 11 | envira
# Processing Record 24 of Set 11 | strezhevoy
# Processing Record 25 of Set 11 | akyab
# Processing Record 26 of Set 11 | iquitos
# Processing Record 27 of Set 11 | samarai
# Processing Record 28 of Set 11 | petropavlovka
# Processing Record 29 of Set 11 | moerai
# Processing Record 30 of Set 11 | port blair
# Processing Record 31 of Set 11 | fortuna
# Processing Record 32 of Set 11 | chara
# Processing Record 33 of Set 11 | dalby
# Processing Record 34 of Set 11 | lodwar
# Processing Record 35 of Set 11 | leh
# Processing Record 36 of Set 11 | lady frere
# Processing Record 37 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 11 | juneau
# Processing Record 39 of Set 11 | dalvik
# Processing Record 40 of Set 11 | ulaangom
# Processing Record 41 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 43 of Set 11 | revelstoke
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | manta
# Processing Record 46 of Set 11 | haines junction
# Processing Record 47 of Set 11 | baykit
# Processing Record 48 of Set 11 | brookhaven
# Processing Record 49 of Set 11 | jaisalmer
# Processing Record 50 of Set 11 | cedar city
# Processing Record 1 of Set 12 | warrnambool
# Processing Record 2 of Set 12 | amarwara
# Processing Record 3 of Set 12 | tadine
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | hakui
# Processing Record 6 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 7 of Set 12 | gat
# Processing Record 8 of Set 12 | bauska
# Processing Record 9 of Set 12 | los llanos de aridane
# Processing Record 10 of Set 12 | tazovskiy
# Processing Record 11 of Set 12 | jiwani
# Processing Record 12 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 12 | london
# Processing Record 14 of Set 12 | mandera
# Processing Record 15 of Set 12 | broken hill
# Processing Record 16 of Set 12 | inta
# Processing Record 17 of Set 12 | alugan
# Processing Record 18 of Set 12 | zaprudnya
# Processing Record 19 of Set 12 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 20 of Set 12 | ambon
# Processing Record 21 of Set 12 | phek
# Processing Record 22 of Set 12 | cairns
# Processing Record 23 of Set 12 | hobyo
# Processing Record 24 of Set 12 | abu dhabi
# Processing Record 25 of Set 12 | laguna
# Processing Record 26 of Set 12 | dalnegorsk
# Processing Record 27 of Set 12 | owase
# Processing Record 28 of Set 12 | ferme-neuve
# Processing Record 29 of Set 12 | noshiro
# Processing Record 30 of Set 12 | padang
# Processing Record 31 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 32 of Set 12 | cootamundra
# Processing Record 33 of Set 12 | dhidhdhoo
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | beloha
# Processing Record 36 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 12 | timizart
# Processing Record 38 of Set 12 | kita
# Processing Record 39 of Set 12 | ko samui
# Processing Record 40 of Set 12 | garmsar
# Processing Record 41 of Set 12 | winnemucca
# Processing Record 42 of Set 12 | florianopolis
# Processing Record 43 of Set 12 | dunedin
# Processing Record 44 of Set 12 | portree
# Processing Record 45 of Set 12 | mayor pablo lagerenza
# Processing Record 46 of Set 12 | rio grande
# Processing Record 47 of Set 12 | arrecife
# Processing Record 48 of Set 12 | general roca
# Processing Record 49 of Set 12 | derzhavinsk
# Processing Record 50 of Set 12 | progreso
# Processing Record 1 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 13 | anloga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 551

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dixon  38.4455 -121.8233     49.86        68         100
# 1   Richards Bay -28.7830   32.0377     72.41        90           5
# 2           Jalu  29.0331   21.5482     49.10        58           0
# 3         Barrow  71.2906 -156.7887     -5.78        77           0
# 4  Mount Gambier -37.8333  140.7667     58.66        58          93
# 5     Bredasdorp -34.5322   20.0403     62.06        84           9
# 6           Tala  30.6803   30.9429     44.49        67           8
# 7         Hobart -42.8794  147.3294     64.26        64          75
# 8      Jamestown  42.0970  -79.2353     19.71        83           0
# 9        Rikitea -23.1203 -134.9692     79.45        75           5
#
#    Wind Speed Country                 Date Current Description
# 0        4.07      US  2023-02-02 04:06:44     overcast clouds
# 1        5.55      ZA  2023-02-02 04:02:51           clear sky
# 2        7.25      LY  2023-02-02 04:06:44           clear sky
# 3       21.85      US  2023-02-02 04:02:44           clear sky
# 4       18.19      AU  2023-02-02 04:06:45          light rain
# 5        1.66      ZA  2023-02-02 04:06:45           clear sky
# 6        6.53      EG  2023-02-02 04:06:45           clear sky
# 7       23.02      AU  2023-02-02 04:03:23       broken clouds
# 8        8.05      US  2023-02-02 04:04:15           clear sky
# 9       15.26      PF  2023-02-02 04:02:02           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dixon      US  38.4455 -121.8233     49.86        68         100
# 1   Richards Bay      ZA -28.7830   32.0377     72.41        90           5
# 2           Jalu      LY  29.0331   21.5482     49.10        58           0
# 3         Barrow      US  71.2906 -156.7887     -5.78        77           0
# 4  Mount Gambier      AU -37.8333  140.7667     58.66        58          93
# 5     Bredasdorp      ZA -34.5322   20.0403     62.06        84           9
# 6           Tala      EG  30.6803   30.9429     44.49        67           8
# 7         Hobart      AU -42.8794  147.3294     64.26        64          75
# 8      Jamestown      US  42.0970  -79.2353     19.71        83           0
# 9        Rikitea      PF -23.1203 -134.9692     79.45        75           5
#
#    Wind Speed Current Description
# 0        4.07     overcast clouds
# 1        5.55           clear sky
# 2        7.25           clear sky
# 3       21.85           clear sky
# 4       18.19          light rain
# 5        1.66           clear sky
# 6        6.53           clear sky
# 7       23.02       broken clouds
# 8        8.05           clear sky
# 9       15.26           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database\WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
